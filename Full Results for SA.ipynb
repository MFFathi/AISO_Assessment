# %% [markdown]
# SIMULATED ANNEALING - TSP RESULTS
#
# Starting City (auto-chosen best): City_26
# Number of cities visited: 10
# Final Distance: 301.95
# Execution Time: 0.0253 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 306.03
# Final Best Distance: 301.95
# Total Improvement: 1.33%
# Number of Improvements: 152
# Acceptances: 305
# Rejections: 695
# Acceptance Rate: 30.50%
# Total Evaluations: 1000
# Initial Temperature: 1000
# Final Temperature: 0.043607
# Cooling Rate: 0.99
#
# TIME COMPLEXITY ANALYSIS
# Max Iterations (I): 1000
# Number of Cities (N): 10
#
# Theoretical Complexity: O(I × N²)
# Estimated Operations: 1000 × 10² = 100,000
# Actual Time per Iteration: 0.025282 ms
# Actual Time per Evaluation: 0.025282 ms
#
# ROUTE DETAILS
# Route: City_26 → City_41 → City_32 → City_11 → City_25 → City_31 → City_50 → City_12 → City_23 → City_1 → City_26
# ![image.png](attachment:image.png)

# %% [markdown]
# SIMULATED ANNEALING - TSP RESULTS
#
# Starting City (auto-chosen best): City_23
# Number of cities visited: 20
# Final Distance: 450.77
# Execution Time: 0.0530 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 450.77
# Final Best Distance: 450.77
# Total Improvement: 0.00%
# Number of Improvements: 163
# Acceptances: 328
# Rejections: 672
# Acceptance Rate: 32.80%
# Total Evaluations: 1000
# Initial Temperature: 1000
# Final Temperature: 0.043607
# Cooling Rate: 0.99
#
# TIME COMPLEXITY ANALYSIS
# Max Iterations (I): 1000
# Number of Cities (N): 20
#
# Theoretical Complexity: O(I × N²)
# Estimated Operations: 1000 × 20² = 400,000
# Actual Time per Iteration: 0.052991 ms
# Actual Time per Evaluation: 0.052991 ms
#
# ROUTE DETAILS
# Route: City_23 → City_14 → City_12 → City_43 → City_31 → City_25 → City_11 → City_32 → City_45 → City_41 → City_26 → City_5 → City_13 → City_1 → City_28 → City_35 → City_6 → City_37 → City_30 → City_50 → City_23
# ![image.png](attachment:image.png)

# %% [markdown]
# SIMULATED ANNEALING - TSP RESULTS
#
# Starting City (auto-chosen best): City_12
# Number of cities visited: 30
# Final Distance: 536.77
# Execution Time: 0.0849 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 536.77
# Final Best Distance: 536.77
# Total Improvement: 0.00%
# Number of Improvements: 179
# Acceptances: 348
# Rejections: 652
# Acceptance Rate: 34.80%
# Total Evaluations: 1000
# Initial Temperature: 1000
# Final Temperature: 0.043607
# Cooling Rate: 0.99
#
# TIME COMPLEXITY ANALYSIS
# Max Iterations (I): 1000
# Number of Cities (N): 30
#
# Theoretical Complexity: O(I × N²)
# Estimated Operations: 1000 × 30² = 900,000
# Actual Time per Iteration: 0.084929 ms
# Actual Time per Evaluation: 0.084929 ms
#
# ROUTE DETAILS
# Route: City_12 → City_43 → City_31 → City_25 → City_11 → City_49 → City_20 → City_48 → City_45 → City_32 → City_41 → City_26 → City_27 → City_38 → City_5 → City_13 → City_1 → City_28 → City_23 → City_33 → City_24 → City_14 → City_46 → City_34 → City_37 → City_22 → City_6 → City_35 → City_30 → City_50 → City_12
# ![image.png](attachment:image.png)

# %% [markdown]
# SIMULATED ANNEALING - TSP RESULTS
#
# Starting City (auto-chosen best): City_1
# Number of cities visited: 40
# Final Distance: 573.40
# Execution Time: 0.4196 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 573.40
# Final Best Distance: 573.40
# Total Improvement: 0.00%
# Number of Improvements: 193
# Acceptances: 359
# Rejections: 641
# Acceptance Rate: 35.90%
# Total Evaluations: 1000
# Initial Temperature: 1000
# Final Temperature: 0.043607
# Cooling Rate: 0.99
#
# TIME COMPLEXITY ANALYSIS
# Max Iterations (I): 1000
# Number of Cities (N): 40
#
# Theoretical Complexity: O(I × N²)
# Estimated Operations: 1000 × 40² = 1,600,000
# Actual Time per Iteration: 0.419575 ms
# Actual Time per Evaluation: 0.419575 ms
#
# ROUTE DETAILS
# Route: City_1 → City_13 → City_5 → City_38 → City_44 → City_2 → City_47 → City_48 → City_20 → City_49 → City_31 → City_43 → City_12 → City_24 → City_33 → City_14 → City_21 → City_30 → City_29 → City_50 → City_40 → City_25 → City_11 → City_15 → City_39 → City_32 → City_45 → City_41 → City_26 → City_18 → City_27 → City_28 → City_23 → City_46 → City_34 → City_4 → City_22 → City_6 → City_35 → City_37 → City_1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# SIMULATED ANNEALING - TSP RESULTS
#
#
# Starting City (auto-chosen best): City_20
# Number of cities visited: 50
# Final Distance: 597.06
# Execution Time: 0.8664 seconds
#
#
# ALGORITHM METRICS
#
# Initial Best Distance: 597.06
# Final Best Distance: 597.06
# Total Improvement: 0.00%
# Number of Improvements: 194
# Acceptances: 355
# Rejections: 645
# Acceptance Rate: 35.50%
# Total Evaluations: 1000
# Initial Temperature: 1000
# Final Temperature: 0.043607
# Cooling Rate: 0.99
#
#
# TIME COMPLEXITY ANALYSIS
#
# Max Iterations (I): 1000
# Number of Cities (N): 50
#
# Theoretical Complexity: O(I × N²)
# Estimated Operations: 1000 × 50² = 2,500,000
# Actual Time per Iteration: 0.866421 ms
# Actual Time per Evaluation: 0.866421 ms
#
# ROUTE DETAILS
#
# Route: City_20 → City_48 → City_47 → City_2 → City_44 → City_38 → City_5 → City_13 → City_1 → City_28 → City_27 → City_18 → City_26 → City_41 → City_45 → City_32 → City_7 → City_36 → City_39 → City_11 → City_16 → City_25 → City_15 → City_40 → City_19 → City_42 → City_8 → City_3 → City_29 → City_50 → City_30 → City_21 → City_14 → City_33 → City_9 → City_24 → City_23 → City_46 → City_34 → City_4 → City_22 → City_17 → City_35 → City_6 → City_37 → City_12 → City_43 → City_31 → City_10 → City_49 → City_20
# ![image.png](attachment:image.png)
