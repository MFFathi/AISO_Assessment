# %% [markdown]
# GENETIC ALGORITHM - TSP RESULTS
#
# Starting City (auto-chosen best): City_12
# Number of cities visited: 10
# Final Distance: 301.95
# Execution Time: 43.9661 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 390.05
# Final Best Distance: 301.95
# Total Improvement: 22.59%
# Number of Improvements: 6
# Convergence Generation: 11
# Total Evaluations: 400000
# Final Stagnant Generations: 1989
#
# TIME COMPLEXITY ANALYSIS
# Population Size (P): 200
# Generations (G): 2000
# Number of Cities (N): 10
#
# Theoretical Complexity: O(G × P × N²)
# Estimated Operations: 2000 × 200 × 10² = 40,000,000
# Actual Time per Operation: 0.109915 ms
#
# ROUTE DETAILS
# Route: City_12 → City_50 → City_31 → City_25 → City_11 → City_32 → City_41 → City_26 → City_1 → City_23 → City_12
# ![image.png](attachment:image.png)

# %% [markdown]
# GENETIC ALGORITHM - TSP RESULTS
#
# Starting City (auto-chosen best): City_23
# Number of cities visited: 20
# Final Distance: 445.25
# Execution Time: 46.8464 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 886.65
# Final Best Distance: 445.25
# Total Improvement: 49.78%
# Number of Improvements: 15
# Convergence Generation: 39
# Total Evaluations: 400000
# Final Stagnant Generations: 1961
#
# TIME COMPLEXITY ANALYSIS
# Population Size (P): 200
# Generations (G): 2000
# Number of Cities (N): 20
#
# Theoretical Complexity: O(G × P × N²)
# Estimated Operations: 2000 × 200 × 20² = 160,000,000
# Actual Time per Operation: 0.117116 ms
#
# ROUTE DETAILS
# Route: City_23 → City_13 → City_5 → City_32 → City_45 → City_41 → City_26 → City_28 → City_1 → City_35 → City_6 → City_37 → City_30 → City_50 → City_11 → City_25 → City_31 → City_43 → City_12 → City_14 → City_23
# ![image.png](attachment:image.png)

# %% [markdown]
# GENETIC ALGORITHM - TSP RESULTS
#
# Starting City (auto-chosen best): City_12
# Number of cities visited: 30
# Final Distance: 489.42
# Execution Time: 54.4576 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 1230.50
# Final Best Distance: 489.42
# Total Improvement: 60.23%
# Number of Improvements: 49
# Convergence Generation: 1197
# Total Evaluations: 400000
# Final Stagnant Generations: 803
#
# TIME COMPLEXITY ANALYSIS
# Population Size (P): 200
# Generations (G): 2000
# Number of Cities (N): 30
#
# Theoretical Complexity: O(G × P × N²)
# Estimated Operations: 2000 × 200 × 30² = 360,000,000
# Actual Time per Operation: 0.136144 ms
#
# ROUTE DETAILS
# Route: City_12 → City_43 → City_31 → City_25 → City_11 → City_49 → City_20 → City_48 → City_32 → City_45 → City_41 → City_5 → City_38 → City_26 → City_27 → City_28 → City_13 → City_1 → City_35 → City_6 → City_22 → City_37 → City_34 → City_46 → City_23 → City_33 → City_24 → City_14 → City_30 → City_50 → City_12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# GENETIC ALGORITHM - TSP RESULTS
#
# Starting City (auto-chosen best): City_1
# Number of cities visited: 40
# Final Distance: 629.75
# Execution Time: 56.3002 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 1730.31
# Final Best Distance: 629.75
# Total Improvement: 63.60%
# Number of Improvements: 93
# Convergence Generation: 1800
# Total Evaluations: 400000
# Final Stagnant Generations: 200
#
# TIME COMPLEXITY ANALYSIS
# Population Size (P): 200
# Generations (G): 2000
# Number of Cities (N): 40
#
# Theoretical Complexity: O(G × P × N²)
# Estimated Operations: 2000 × 200 × 40² = 640,000,000
# Actual Time per Operation: 0.140750 ms
#
# ROUTE DETAILS
# Route: City_1 → City_28 → City_27 → City_18 → City_26 → City_41 → City_48 → City_20 → City_49 → City_23 → City_34 → City_35 → City_6 → City_22 → City_4 → City_37 → City_46 → City_21 → City_30 → City_50 → City_29 → City_14 → City_33 → City_5 → City_38 → City_44 → City_2 → City_47 → City_45 → City_32 → City_39 → City_15 → City_11 → City_25 → City_40 → City_31 → City_43 → City_12 → City_24 → City_13 → City_1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# GENETIC ALGORITHM - TSP RESULTS
#
# Starting City (auto-chosen best): City_20
# Number of cities visited: 50
# Final Distance: 602.52
# Execution Time: 60.6560 seconds
#
# ALGORITHM METRICS
# Initial Best Distance: 2240.03
# Final Best Distance: 602.52
# Total Improvement: 73.10%
# Number of Improvements: 100
# Convergence Generation: 1626
# Total Evaluations: 400000
# Final Stagnant Generations: 374
#
# TIME COMPLEXITY ANALYSIS
# Population Size (P): 200
# Generations (G): 2000
# Number of Cities (N): 50
#
# Theoretical Complexity: O(G × P × N²)
# Estimated Operations: 2000 × 200 × 50² = 1,000,000,000
# Actual Time per Operation: 0.151640 ms
#
# ROUTE DETAILS
# Route: City_20 → City_44 → City_38 → City_5 → City_1 → City_35 → City_17 → City_6 → City_22 → City_4 → City_37 → City_34 → City_46 → City_21 → City_14 → City_24 → City_9 → City_33 → City_23 → City_13 → City_28 → City_27 → City_18 → City_26 → City_41 → City_2 → City_47 → City_48 → City_45 → City_32 → City_7 → City_36 → City_39 → City_15 → City_11 → City_16 → City_25 → City_40 → City_42 → City_19 → City_8 → City_3 → City_50 → City_29 → City_30 → City_12 → City_43 → City_31 → City_10 → City_49 → City_20
# ![image.png](attachment:image.png)
